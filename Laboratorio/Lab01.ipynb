# %%
## Laboratorio 1
# 01/09/2026
# Lucia

# %%
print ("Mi primer sistema inteligente")
nombre = input ("Escribe su nombre, empezando por su apellido parterno")
matricula = input ("Escribe tu matricula")
promedio = float (input ("Escribe tu promedio"))
# Out:
# Mi primer sistema inteligente
# Escribe su nombre, empezando por su apellido parterno Garcia Aquino Lucia Magdalena
# Escribe tu matricula 20243L601152
# Escribe tu promedio 8.8

# %%
print ("Datos almacenados")
print ("Nombre: ", nombre)
print ("Matricula: ", matricula)
print ("Promedio: ", promedio)
# Out:
# Datos almacenados
# Nombre:  Garcia Aquino Lucia Magdalena
# Matricula:  20243L601152
# Promedio:  8.8

# %%
# Reglas
if promedio>=8.0 and promedio <=10:
    print("Excelente desempeño")
elif promedio<8.0 and promedio >=7.0:
    print("Echale ganas, puedes mejorar")
elif promedio<7.0 and promedio >=6.0:
    print("Necesitas ayuda")
else:
    print("Reprobaste, tienes que hacer recursa")
# Out:
# Excelente desempeño
