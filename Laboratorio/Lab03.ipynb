# %%
### Laboratorio 3: Proposiciones

### **Objetivo:Un videojuego utiliza un agente inteligente enemigo que debe decidir si puede iniciar un ataque contra el jugador.
##Fecha:** 7 de septiembre

# %%
#Proposiciones
P: Se encuentra dentro del rango
Q: El nivel de vida es suficiente
R: Existe municiones disponibles
S: Esta visible
T: No existe amenaza cercana
U: No esta aturdido

# %%
# Definición de variables
rango = True #si esta dentro del rango
nivelVida = True #si tiene vida suficiente
municiones = True #si cuenta con municiones disponibles
visible = True #si esta visible el jugador
amenaza = False #No existe amenaza cercana
aturdido = False #No esta aturdido

# %%
### Reglas
El jugador está dentro del rango Y es visible Y el enemigo tiene suficiente vida Y tiene munición disponible
Y no existe una amenaza cercana Y no esta aturdido.
# Out:
#   Cell In[7], line 2
#     El jugador está dentro del rango Y es visible Y el enemigo tiene suficiente vida Y tiene munición disponible
#        ^
# SyntaxError: invalid syntax

# %%
puedeAtacar = (rango==True and visible==True and nivelVida==True and municiones==True and amenaza==False and aturdido==False)

# %%
print("El agente enemigo puede atacar?" , puedeAtacar)
# Out:
# El agente enemigo puede atacar? True

# %%
print (" == Agente Enemigo Inteligente ==")
print ("Development by Lucia")

rango = input("El jugador se encuentra dentro del rango(s/n): ").lower() == "s"
visible = input("El jugador esta visible(s/n): ").lower() == "s"
nivelVida = input("El enemigo tiene suficiente vida(s/n): ").lower() == "s"
municiones = input("El enemigo tiene suficientes municiones(s/n): ").lower() == "s"
amenaza = input("Existe una amenaza cercana? (s/n): ").lower() == "n"
aturdido = input ("El enemigo no esta aturdido? (s/n): ").lower() == "n"

puedeAtacar = (rango==True and visible==True and nivelVida==True and municiones==True and amenaza==False and aturdido==False)

print ("Desicion del agente")
if puedeAtacar == True :
    print("El agente puede atacar: es tu momento!!!!!!!!!!")
else:
    print("Escondete!!!!!!!!! No es tu momento de atacar")
# Out:
#  == Agente Enemigo Inteligente ==
# Development by Lucia
# El jugador se encuentra dentro del rango(s/n):  s
# El jugador esta visible(s/n):  n
# El enemigo tiene suficiente vida(s/n):  s
# El enemigo tiene suficientes municiones(s/n):  s
# Existe una amenaza cercana? (s/n):  s
# El enemigo no esta aturdido? (s/n):  n
# Desicion del agente
# Escondete!!!!!!!!! No es tu momento de atacar
